# %%
'''
its extenson of linear regression where there is more than one input to determine the value.
In this we have to take multiple inputs and preditd, in linear regressiso we had to predit
from the graph with line
ie.(y=mx+c),
as one input x. However, here there are multiple inputs lets say 
x1, x2, y then we find by x1y,x2y and then we plot. Due to multiple input we use eqsn of plain
ie. y=m1x1+m2x2+m3x3+.......+c
'''
# Out:
# '\nits extenson of linear regression where there is more than one input to determine the value.\nIn this we have to take multiple inputs and preditd, in linear regressiso we had to predit\nfrom the graph with line\nie.(y=mx+c),\nas one input x. However, here there are multiple inputs lets say \nx1, x2, y then we find by x1y,x2y and then we plot. Due to multiple input we use eqsn of plain\nie. y=m1x1+m2x2+m3x3+.......+c\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataset=pd.read_csv("Mall_Customers.csv")
dataset.head(3)
# Out:
#    Experience  Age  Annual Income (k$)  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0           7   19                  15         NaN         NaN         NaN
# 1           3   21                  15         NaN         NaN         NaN
# 2           9   20                  16         NaN         NaN         NaN

# %%
dataset.shape
# Out:
# (200, 6)

# %%
dataset.isnull().sum()
# Out:
# Experience              0
# Age                     0
# Annual Income (k$)      0
# Unnamed: 3            200
# Unnamed: 4            200
# Unnamed: 5            200
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
# Out:
# <Axes: >
