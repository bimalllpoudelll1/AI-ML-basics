# %%
# we going to fill datas instead of removing
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
dataset=pd.read_csv(r"C:\Users\dell\Documents\excells\data1.csv")
dataset.head(2)
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 0  Abbotsford     85 Turner St      2    h  1480000      S  Biggin  3/12/2016
# 1  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin   4/2/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5      3067  ...         1  1.0       202           NaN        NaN
# 1       2.5      3067  ...         1  0.0       156          79.0     1900.0
#
#    CouncilArea Lattitude  Longtitude             Regionname Propertycount
# 0        Yarra  -37.7996    144.9984  Northern Metropolitan          4019
# 1        Yarra  -37.8079    144.9934  Northern Metropolitan          4019
#
# [2 rows x 21 columns]

# %%
# to fill any categorical data in a coloumn find out the mode ie. 
# the most used data and replace in the null value.. heree it is "Moreland"
# dataset["CouncilArea"].mode()[0]
dataset["CouncilArea"].fillna(dataset["CouncilArea"].mode()[0],inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_26924\2346217526.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["CouncilArea"].fillna(dataset["CouncilArea"].mode()[0],inplace=True)

# %%
# when we want to fill mode in object type data 
dataset.select_dtypes(include=object).isnull().sum()
# Out:
# Suburb         0
# Address        0
# Type           0
# Method         0
# SellerG        0
# Date           0
# CouncilArea    0
# Regionname     0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea         0
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
# # if you want to fill specific value to all the data then use fillna not effective tho
# dataset.fillna(10)

# %%
# for the backward filling we need bfill // and ffill for forward filiing
# WE CAN USE AXIS=0 FOR COPYING ROWS AND FILLING EMPTY AND AXIS=1 IN COPYING COLUMN DATA TO ANOTGER COLUM
# dataset.fillna(method="ffill", axis=1)
# dataset.fillna(method="bfill", axis=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    13580 non-null  object
# ...

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea         0
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64
