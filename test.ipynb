# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset=pd.read_csv(r'C:\Users\dell\Documents\excells\data1.csv')
dataset.head(4)
# Out:
# Matplotlib is building the font cache; this may take a moment.
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1  1.0       202           NaN
# 1   4/2/2016       2.5      3067  ...         1  0.0       156          79.0
# 2   4/3/2017       2.5      3067  ...         2  0.0       134         150.0
# 3   4/3/2017       2.5      3067  ...         2  1.0        94           NaN
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# ...

# %%
dataset.shape
# Out:
# (13580, 21)

# %%
dataset.shape[0]
# Out:
# 13580

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(13256)

# %%
dataset.shape[1]
# Out:
# 21

# %%
(dataset.isnull().sum()/dataset.shape[1])*100
# Out:
# Suburb               0.000000
# Address              0.000000
# Rooms                0.000000
# Type                 0.000000
# Price                0.000000
# Method               0.000000
# SellerG              0.000000
# Date                 0.000000
# Distance             0.000000
# Postcode             0.000000
# Bedroom2             0.000000
# Bathroom             0.000000
# Car                295.238095
# Landsize             0.000000
# BuildingArea     30714.285714
# YearBuilt        25595.238095
# CouncilArea       6519.047619
# Lattitude            0.000000
# Longtitude           0.000000
# Regionname           0.000000
# Propertycount        0.000000
# dtype: float64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(4.648292306613367)

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
dataset.isnull().sum()/dataset.shape[0]*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price             0.000000
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.000000
# Car               0.456554
# Landsize          0.000000
# BuildingArea     47.496318
# YearBuilt        39.580265
# CouncilArea      10.081001
# Lattitude         0.000000
# Longtitude        0.000000
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
dataset.notnull().sum().sum()
# Out:
# np.int64(271924)

# %%
# now for using matplotliv and seaborn to make graphs and finding the nature of data

# %%
sns.heatmap(dataset.notnull())
plt.show()
