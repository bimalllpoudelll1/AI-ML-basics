# %%
# for missing value handeling
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
dataset=pd.read_csv(r"C:\Users\dell\Documents\excells\data1.csv")
dataset.head(3)
# Out:
#        Suburb          Address  Rooms Type    Price Method SellerG       Date  \
# 0  Abbotsford     85 Turner St      2    h  1480000      S  Biggin  3/12/2016
# 1  Abbotsford  25 Bloomburg St      2    h  1035000      S  Biggin   4/2/2016
# 2  Abbotsford     5 Charles St      3    h  1465000     SP  Biggin   4/3/2017
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5      3067  ...         1  1.0       202           NaN        NaN
# 1       2.5      3067  ...         1  0.0       156          79.0     1900.0
# 2       2.5      3067  ...         2  0.0       134         150.0     1900.0
#
#    CouncilArea Lattitude  Longtitude             Regionname Propertycount
# 0        Yarra  -37.7996    144.9984  Northern Metropolitan          4019
# 1        Yarra  -37.8079    144.9934  Northern Metropolitan          4019
# 2        Yarra  -37.8093    144.9944  Northern Metropolitan          4019
#
# [3 rows x 21 columns]

# %%
# initial shape of data

dataset.shape
# Out:
# (13580, 21)

# %%
# size after deleting a coloumn
dataset.shape
# Out:
# (13580, 21)

# %%
#size after removing all the rows with missing value
dataset.shape
# Out:
# (13580, 21)

# %%
# fining the % of loosed data from row
((13580-7448)/13580)*100
# we lost around 45% of the data
# Out:
# 45.154639175257735

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
#for removing any coloum from the data
dataset.drop(columns=["BuildingArea"],inplace=True)

# %%
sns.heatmap(dataset.isnull())
plt.show() 
# heatmap without column "BuildingArea"

# %%
# for removing all missing data from the data
dataset.dropna(inplace=True)
